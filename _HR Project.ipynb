# %%
df=pd.read_csv('TA Aisha 29th Files.csv')
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head()
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
#Q--Go through the dataset and derive some inference relatedd to it so that we can have solutions for the company.

# %%
df.isnull().sum() # sum is for each and every columns
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3008

# %%
df.info() # it for summary of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df[df.duplicated()]  # show the Duplicates rows.
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
# let's drop the duplicate values.
#df.drop_duplicates()
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11991 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      11991 non-null  float64
#  1   lastEvaluation         11991 non-null  float64
#  2   numberOfProjects       11991 non-null  int64
#  3   avgMonthlyHours        11991 non-null  int64
#  4   timeSpent.company      11991 non-null  int64
#  5   workAccident           11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotionInLast5years  11991 non-null  int64
#  8   dept                   11991 non-null  object
#  9   salary                 11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %%
#plot a box plot separetely for the columns avgMonthly hours,numberofprojects,timeSpent.company

# %%
sns.boxplot(df['avgMonthlyHours'])
# Out:
# <Axes: ylabel='avgMonthlyHours'>

# %%
sns.boxplot(df['timeSpent.company'])
# Out:
# <Axes: ylabel='timeSpent.company'>

# %%
sns.boxplot(df['numberOfProjects'])
# Out:
# <Axes: ylabel='numberOfProjects'>

# %%
#a countplot is used to show the frequency of categories in a categorical variable.
fig= plt.subplots(1,2,figsize=(10,6))

plt.subplot(1,2,1)
sns.countplot(data=df,x='numberOfProjects')

plt.subplot(1,2,2)
sns.countplot(data=df,x='numberOfProjects',hue='left')
plt.show()

#conclusion
# In the graph ,most of the employees are stable(full time) in the range 3 to 5.
#So,company should focus on giving the project to the employees in the range of 3 to 5 project.

# %%
# Focus on giving people projects within the range of 3-5 because they're most probably going to stay.
#Countplot--avgmonhours-use hue=left

sns.countplot(df,x='avgMonthlyHours',hue='left')
plt.show()
# not properly to get inteference from this graph so will histograph

# %%
sns.histplot(df,x='avgMonthlyHours',hue='left',bins= 10) # Bins define the number of division of the data
plt.show()

# %%
# most preferable number of working hour is between 100-300.Beyond that attrition rate is high
#so,company should focus on keeping the working hours within the range of 100-200 in order to avoid the attrition.

# %%
#Countplot--timepsent -hue left.
sns.countplot(df,x='timeSpent.company',hue='left')
plt.show()

# %%
sns.countplot(df,x='promotionInLast5years',hue='left')
# Out:
# <Axes: xlabel='promotionInLast5years', ylabel='count'>

# %%
#In the given ,clearly can been that the only one persons got promotion in the time spent of 10 years and 
#no promotion in with 5 years of the time spent
so,lack of promotion is hiting hard to the company in terms of attrion.
    Therefore,Company should give promotion to the their employee on regular interval alongwith salary hike and bettertreatment to retain their e

# %%
sns.countplot(df,x='workAccident',hue='left')
plt.show()

# %%
# As much we can see there is no work accident but empoyee on notice period --it means there is other factors-
#Therefore,company is recommedated that maintain the work enviroment and work culture,safety ,measures within the company.

# %%
sns.countplot(df,x='dept',hue='left')
plt.xticks(rotation = 90) # for see the data visible on x-axis
plt.show()

# %%
# As per teh shown data,sales,technical ,support department are facing the highest number of attrition in the company
# Due to this highest number of attrition is affecting the department.However,it is just assuption but it is sure that the attrion creates 
#a negative envirnment in the comapny.
#So,The company should priotise these deaprtent to identify the problem & work upon them.

# %%
sns.countplot(df,x='salary',hue='left')
plt.show()

# %%
# At the end ,salary is more important, On the above data ,the appropriate amount of salry should be provided 
#aloghtwith compensation for medium and low salry.
